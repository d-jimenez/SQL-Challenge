# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
import os

# %%
#Import Pandas
import pandas as pd

# Import Matplot lib
import matplotlib
from matplotlib import style
style.use('seaborn')
import matplotlib.pyplot as plt

# %%
# Import ppostgres username and password - DO NOT PUSH TO GitHub
from userpass_key import userpass

# %%
# Create engine using the HPEmployeed DataBase from PostgresSQL
engine = create_engine(f'postgresql://{userpass}@localhost:5432/HPEmployees_db')

# %%
# Use the Inspector to explore the database and print the table names
# YOUR CODE HERE

inspector=inspect(engine)

inspector.get_table_names()
# Out:
# ['title', 'employees', 'salaries', 'dept_emp', 'departments', 'dept_manager']

# %%
# Use Inspector to print the column names and types for Salaries Table

columns=inspector.get_columns('salaries')
# columns
for each_column in columns:
    print(f" {each_column['name']} - {each_column['type']}")
# Out:
#  emp_no - VARCHAR
#  salary - INTEGER

# %%
# Use Inspector to print the column names and types for Title Table

columns=inspector.get_columns('title')
# columns
for each_column in columns:
    print(f" {each_column['name']} - {each_column['type']}")
# Out:
#  title_id - VARCHAR
#  title - VARCHAR

# %%
# Use Inspector to print the column names and types for Employees Table

columns=inspector.get_columns('employees')
# columns
for each_column in columns:
    print(f" {each_column['name']} - {each_column['type']}")
# Out:
#  emp_no - VARCHAR
#  emp_title_id - VARCHAR
#  birth_date - DATE
#  first_name - VARCHAR
#  last_name - VARCHAR
#  sex - VARCHAR
#  hire_date - DATE

# %%
# Reflect Database into ORM class
Base = automap_base()
Base.prepare(engine, reflect=True)
Salaries = Base.classes.salaries
Titles = Base.classes.title
Employees=Base.classes.employees

# %%
# Start a session to query the database
session = Session(engine)

# %%
emp_sal=session.query(Salaries.emp_no,Salaries.salary).all()
emp_sal
# Out:
# [('10001', 60117),
#  ('10002', 65828),
#  ('10003', 40006),
#  ('10004', 40054),
#  ('10005', 78228),
#  ('10006', 40000),
#  ('10007', 56724),
#  ('10008', 46671),
#  ('10009', 60929),
#  ('10010', 72488),
#  ('10011', 42365),
#  ('10012', 40000),
#  ('10013', 40000),
#  ('10014', 46168),
#  ('10015', 40000),
#  ('10016', 70889),
#  ('10017', 71380),
#  ('10018', 55881),
#  ('10019', 44276),
#  ('10020', 40000),
#  ('10021', 55025),
#  ('10022', 40000),
#  ('10023', 47883),
#  ('10024', 83733),
#  ('10025', 40000),
#  ('10026', 47585),
#  ('10027', 40000),
#  ('10028', 48859),
#  ('10029', 63163),
#  ('10030', 66956),
#  ('10031', 40000),
#  ('10032', 48426),
#  ('10033', 51258),
#  ('10034', 47561),
#  ('10035', 41538),
#  ('10036', 42819),
#  ('10037', 40000),
#  ('10038', 40000),
#  ('10039', 40000),
#  ('10040', 52153),
#  ('10041', 56893),
#  ('10042', 81662),
#  ('10043', 49324),
#  ('10044', 40919),
#  ('10045', 41971),
#  ('10046', 40000),
#  ('10047', 54982),
# ...

# %%
# Return a joined table of Employees, Salaries and Titles using a join of the three then a filter.
sel=[Employees.emp_no, Employees.emp_title_id, Salaries.emp_no, Salaries.salary, Titles.title_id, Titles.title]

emp_salary=session.query(*sel).filter(Employees.emp_no==Salaries.emp_no).filter(Employees.emp_title_id==Titles.title_id).all()

# %%
#Create DataFrame from query

df=pd.DataFrame(emp_salary,columns=["Employees.emp_no", "Employees.emp_title_id", "Salaries.emp_no", "Salaries.salary", "Titles.title_id", "Titles.title"])
df
# Out:
#        Employees.emp_no Employees.emp_title_id Salaries.emp_no  \
# 0                246449                  s0001          246449
# 1                 67799                  e0002           67799
# 2                299898                  s0001          299898
# 3                492723                  e0003          492723
# 4                411614                  e0003          411614
# ...                 ...                    ...             ...
# 300019           421177                  e0002          421177
# 300020           473844                  s0001          473844
# 300021           275129                  e0003          275129
# 300022            81057                  e0003           81057
# 300023           464503                  s0002          464503
#
#         Salaries.salary Titles.title_id     Titles.title
# 0                 87084           s0001            Staff
# 1                 48111           e0002         Engineer
# ...

# %%
#Create a histogram to visualize the most common salary ranges for employees.
#Histogrma indicates that salaries are highly left skewed.
df["Salaries.salary"].hist(bins=3)

plt.title('Salary Histogram')

plt.xlabel('Salary Bin')

plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
#Create a bar chart of average salary by title.

title_salary=df.groupby('Titles.title')["Salaries.salary"].mean()

title_salary

title_salary.plot(kind='bar')

plt.title('Mean Salary by Job Title')

plt.xlabel('Title')

plt.ylabel('Mean Salary')
# Out:
# Text(0, 0.5, 'Mean Salary')

# %%
#"Search your ID number." You look down at your badge to see that your employee ID number is 499942.
#Appears as thouy my salary of 40,000 is less than the mean salary for my job title from data based in the 1980s and 1990s.
#HAHA 

df_499942=df.loc[df['Employees.emp_no']=='499942',:]

df_499942
# Out:
#       Employees.emp_no Employees.emp_title_id Salaries.emp_no  \
# 21095           499942                  e0004          499942
#
#        Salaries.salary Titles.title_id      Titles.title
# 21095            40000           e0004  Technique Leader
